# %% [markdown]
# <a href="https://colab.research.google.com/github/Void-Brain70/Coursera_TF_AI_ML_DL/blob/main/Coursera_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# If you are using the colabs, you'll use the latest version of TensorFlow that Google Colaboratory supports, which, at time of writing is 1.13. 
# You can replace this with 2.0 by adding a codeblock containing: 
# !pip install tensorflow==2.0.0-alpha0

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

import matplotlib.pyplot as plt
import numpy as np
import cv2
import os
import PIL

from keras.layers import Dense
from keras.utils.np_utils import to_categorical

# %% [markdown]
# **y = 2x-1**

# %%
from google.colab import files 
from IPython.display import Image
u = files.upload()
# Out:
#      <input type="file" id="files-c5906ce5-49d9-4e6b-b43d-375ec644067c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c5906ce5-49d9-4e6b-b43d-375ec644067c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cour6.PNG to cour6 (1).PNG

# %%
Image('cour6.PNG',width=700)

# %%
x = np.array([-1.0,0.0,1.0,2.0,3.0,4.0],dtype=float)
y = np.array([-3.0,-1.0,1.0,3.0,5.0,7.0],dtype=float)

# %%
model = keras.Sequential([
    keras.layers.Dense(units=1,input_shape=[1])
])

model.compile(
    optimizer = 'sgd', # the optimizer thinks about how good or how badly the guess was done using the data from the loss function
    loss = 'mean_squared_error'
)

model.fit(x,y,epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 482ms/step - loss: 38.3577
# Epoch 2/500
# 1/1 [==============================] - 0s 6ms/step - loss: 30.5263
# Epoch 3/500
# 1/1 [==============================] - 0s 4ms/step - loss: 24.3577
# Epoch 4/500
# 1/1 [==============================] - 0s 4ms/step - loss: 19.4975
# Epoch 5/500
# 1/1 [==============================] - 0s 4ms/step - loss: 15.6669
# Epoch 6/500
# 1/1 [==============================] - 0s 5ms/step - loss: 12.6465
# Epoch 7/500
# 1/1 [==============================] - 0s 7ms/step - loss: 10.2636
# Epoch 8/500
# 1/1 [==============================] - 0s 5ms/step - loss: 8.3823
# Epoch 9/500
# 1/1 [==============================] - 0s 2ms/step - loss: 6.8960
# Epoch 10/500
# 1/1 [==============================] - 0s 3ms/step - loss: 5.7204
# Epoch 11/500
# 1/1 [==============================] - 0s 4ms/step - loss: 4.7894
# Epoch 12/500
# 1/1 [==============================] - 0s 3ms/step - loss: 4.0511
# ...

# %%
# y = 2x-1
print(model.predict([10.0]))
# Out:
# [[18.977886]]
